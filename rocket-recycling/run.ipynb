# %%
# %run train_dqn.py
# Out:
# episode id: 1201, episode reward: 11.558
# episode id: 1202, episode reward: 17.575
# episode id: 1203, episode reward: 8.286
# episode id: 1204, episode reward: 10.086
# episode id: 1205, episode reward: 23.676
# episode id: 1206, episode reward: 17.997
# episode id: 1207, episode reward: 13.461
# episode id: 1208, episode reward: 29.763
# episode id: 1209, episode reward: 28.188
# episode id: 1210, episode reward: 27.105
# episode id: 1211, episode reward: 19.156
# episode id: 1212, episode reward: 17.745
# episode id: 1213, episode reward: 16.165
# episode id: 1214, episode reward: 27.708
# episode id: 1215, episode reward: 11.478
# episode id: 1216, episode reward: 10.176
# episode id: 1217, episode reward: 13.296
# episode id: 1218, episode reward: 20.189
# episode id: 1219, episode reward: 8.275
# episode id: 1220, episode reward: 17.783
# episode id: 1221, episode reward: 21.535
# episode id: 1222, episode reward: 15.888
# episode id: 1223, episode reward: 25.718
# ...
